# %% [markdown]
# # Jupyter Notebook
# Jupyter Notebook is a tool that allows you to develop code in a web browser. It enables you to run code in cells, and easily view results such as graphs, tables, images, and even videos, making it especially useful for data-related tasks.
#
# >It seems like a program that anyone working with Python should definitely try!

# %% [markdown]
# ![image.png](attachment:6fb9367d-6ed8-4401-b819-7f82da2795d4.png)

# %% [markdown]
# ![Capture23.JPG](attachment:bded07e6-fa1a-4e31-ad03-ff9da856f47b.JPG)

# %% [markdown]
# ## Lorem!
#
# 1. lorem
# 1. lorem2
# 1. lorem3
# 1. lorem4
# 1. lorem5

# %% [markdown]
# ## lorem
#
# loremloremloremloremloremloremloremlorem.
# [pandas](https://pandas.pydata.org/docs/user_guide/style.html)

# %%
# %%HTML
# <iframe width="640" height="360" src="https://www.youtube.com/embed/dJfq-eCi7KI" title="아나콘다 환경 설정 및 주피터 노트북 사용법" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="640" height="360" src="https://www.youtube.com/embed/dJfq-eCi7KI" title="아나콘다 환경 설정 및 주피터 노트북 사용법" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# # Python Basic

# %%
print("hello world")
# Out:
# hello world

# %%
print("welcome")
# Out:
# welcome

# %%
name = "name"
print(name)
# Out:
# name

# %%
print("ctrl+enter : run selected cell")
# Out:
# ctrl+enter : run selected cell

# %%
print("shift+enter: run selected cell and move to the next cell")
# Out:
# shift+enter: run selected cell and move to the next cell

# %%
print("Alt+Enter: run selected cell and insert a cell on the next position")
# Out:
# Alt+Enter: run selected cell and insert a cell on the next position

# %%
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %% [markdown]
# # Module

# %%
import random
print(random.randint(1,45))
# Out:
# 31

# %%
random.randint??
# Out:
# Signature: random.randint(a, b)
# Docstring:
# Return random integer in range [a, b], including both end points.
#
# Source:
#     def randint(self, a, b):
#         """Return random integer in range [a, b], including both end points.
#         """
#
#         return self.randrange(a, b+1)
# File:      c:\users\haeun.kim\anaconda3\lib\random.py
# Type:      method

# %%
num=3

# %%
num*=2

# %%
num+=4

# %%
print(num)
# Out:
# 10

# %%
# import time
# for i in range(100):
#     print(i)
#     time.sleep(1)

# %% [markdown]
# ---
#
# ## Visualization Example 1: Graph
#
# - With matplotlib, you can create various types of graphs and view the results immediately.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 5, 2, 14], [1, 4, 9, 16])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# ## Visualization Example 1: Table
# - Pandas is very useful for analyzing complex data.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

df = pd.DataFrame({
    "strings": ["Adam", "Mike"],
    "ints": [1, 3],
    "floats": [1.123, 1000.23]
})
df.style \
  .format(precision=3, thousands=".", decimal=",") \
  .format_index(str.upper, axis=1) \
  .relabel_index(["row 1", "row 2"], axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5b958">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b958_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_5b958_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_5b958_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b958_level0_row0" class="row_heading level0 row0" >row 1</th>
#       <td id="T_5b958_row0_col0" class="data row0 col0" >Adam</td>
#       <td id="T_5b958_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_5b958_row0_col2" class="data row0 col2" >1,123</td>
#     </tr>
#     <tr>
#       <th id="T_5b958_level0_row1" class="row_heading level0 row1" >row 2</th>
#       <td id="T_5b958_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_5b958_row1_col1" class="data row1 col1" >3</td>
# ...

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2021-01-01", periods=10),
                          columns=["Tokyo", "Beijing"])

def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"

def make_pretty(styler):
    styler.set_caption("Weather Conditions")
    styler.format(rain_condition)
    styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    return styler

weather_df
# Out:
#                Tokyo   Beijing
# 2021-01-01  0.098964  1.091989
# 2021-01-02  4.783666  3.702319
# 2021-01-03  4.337779  3.834605
# 2021-01-04  0.038028  3.097047
# 2021-01-05  0.032605  2.250363
# 2021-01-06  2.641665  2.780421
# 2021-01-07  4.347341  4.177199
# 2021-01-08  0.409148  2.006754
# 2021-01-09  2.079839  4.880523
# 2021-01-10  4.110380  2.303295
